# %%
import os
import re
import pandas as pd
from pathlib import Path
from openai import OpenAI
from dotenv import load_dotenv

# %%
folder = Path('../sheets-cleanup/processed_sheets/')
files = list(folder.glob('*.xlsx'))

print(f'Total de arquivos: {len(files)}')
# Out:
# Total de arquivos: 184

# %%
load_dotenv()
client = OpenAI()


PROMPT_TEMPLATE = """
Você é um sistema rigoroso de classificação fiscal especializado em motopeças. Sua única função é ler a descrição de um produto e classificá-lo em UM dos NCMs fornecidos na lista abaixo.

LISTA DE NCMs PERMITIDOS:
87141000 - Partes e acessórios gerais (carenagens, retrovisores, suportes, peças plásticas, componentes diversos)
40114000 - Pneus novos para motocicletas
40139000 - Câmaras de ar para motocicletas
84839000 - Partes de transmissão (engrenagens, eixos, componentes mecânicos)
73151100 - Correntes de rolos (corrente de transmissão)
85122000 - Aparelhos de iluminação ou sinalização (faróis, lanternas, piscas/setas)
85113000 - Bobinas de ignição
85114000 - Motor de partida/arranque
87149400 - Freios e suas partes (discos, pastilhas, lonas, sistemas de freio)
94012000 - Assentos para veículos (bancos, capas de banco)

REGRAS OBRIGATÓRIAS (SIGA RIGOROSAMENTE):
1. FORMATO DE SAÍDA: Retorne EXCLUSIVAMENTE os 8 dígitos numéricos do NCM correspondente. Não adicione pontos, hifens, palavras, saudações ou explicações.
2. FOCO NA PEÇA: A descrição de entrada contém [Nome da Peça + Marca + Modelo/Ano da Moto + Código Interno]. Ignore a marca, o modelo da moto e o código. Foque APENAS no nome da peça para fazer a classificação.
3. PROIBIDO ALUCINAR: Você só pode usar os NCMs da lista acima. Se você ficar em dúvida ou o produto não for freio, iluminação, pneu, transmissão, motor de partida ou banco, classifique-o obrigatoriamente na categoria geral: 87141000.

Descrição do produto:
{description}
"""
NCM_COLUMN = 'NCM'

# %%
def get_ncm(description: str) -> str:
    prompt = PROMPT_TEMPLATE.format(description=description)

    response = client.chat.completions.create(
        model="gpt-4.1-mini",
        temperature=0,
        messages=[
            {"role": "user", "content": prompt}
        ],
    )

    raw_text = response.choices[0].message.content.strip()

    # Extrai apenas 8 dígitos
    match = re.search(r"\b\d{8}\b", raw_text)
    if match:
        return match.group(0)

    return "None"

# %%
def process_sheets():
    print(f"Total de arquivos encontrados: {len(files)}\n")

    df_final = pd.DataFrame()

    for file_path in files[:3]:
        print(f"Processando arquivo: {file_path.name}")

        df = pd.read_excel(file_path, usecols=[1, 2, 3, 4], dtype=str, index_col=False)

        if df.empty:
            print("Planilha vazia.\n")
            break

        if df.shape[1] < 2:
            print("Coluna descrição não encontrada.\n")
            break

        first_description = str(df.iloc[0, 1]).strip()

        if not first_description or first_description.lower() == "nan":
            print("Descrição não encontrada.\n")
            break

        print(f"Descrição encontrada: {first_description}")

        ncm_code = get_ncm(first_description)

        print(f"NCM encontrado: {ncm_code}")

        df[NCM_COLUMN] = ncm_code
        df_final = pd.concat([df_final, df], ignore_index=True)

        print(f"Atualizado: {file_path.name}\n")

    print('Finalizado')
    return df_final

# %%
processed_df = process_sheets()
# Out:
# Total de arquivos encontrados: 184
#
# Processando arquivo: SENSOR OXIGÊNIO.xlsx
# Descrição encontrada: SENSOR OXIGENIO IRON CB300 2010 A 2015 201614
# NCM encontrado: 85119000
# Atualizado: SENSOR OXIGÊNIO.xlsx
#
# Processando arquivo: SUPORTE CELULAR 13_02.xlsx
# Descrição encontrada: SUPORTE CELULAR LEHMOX PRETO 2259
# NCM encontrado: 87141000
# Atualizado: SUPORTE CELULAR 13_02.xlsx
#
# Processando arquivo: SILICONE 15_02_.xlsx
# Descrição encontrada: SILICONE ACETICO CINZA WMAX
# NCM encontrado: 38249900
# Atualizado: SILICONE 15_02_.xlsx
#
# Finalizado

# %%
processed_df.head()
# Out:
#       CÓD. BARRA                                          DESCRIÇÃO  \
# 0   070341180129      SENSOR OXIGENIO IRON CB300 2010 A 2015 201614
# 1  7909201087694  SENSOR OXIGENIO CONDOR SCOOTER NMAX160 2017 A ...
# 2  7909201058670              SENSOR OXIGENIO CONDOR NEO115 1210385
# 3  6920240718036                  SUPORTE CELULAR LEHMOX PRETO 2259
# 4  6920240718036               SUPORTE CELULAR LEHMOX PRATEADO 2259
#
#   QUANTIDADE PREÇO       NCM
# 0          2   210  90318000
# 1          1   NaN  90318000
# 2          2    60  90318000
# 3          5   NaN  39269090
# 4         10   NaN  39269090

# %%
processed_df.to_excel('../sanitization/products_with_ncm.xlsx', index=False)
