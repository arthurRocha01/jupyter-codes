# %%
import pandas as pd
from pathlib import Path

# %%
folder = Path('./sheets')
files = list(folder.glob('*.xlsx'))
print(len(files))
# Out:
# 303

# %%
all_dfs = []
for file in files:
    print(file)
    df_temp = pd.read_excel(file, usecols=[0, 1, 2, 3], dtype=str)
    df_temp = df_temp.dropna(how='all')
    all_dfs.append(df_temp)

df = pd.concat(all_dfs, ignore_index=True)
df.info()
# Out:
# sheets/REPARO FREIO.xlsx
# sheets/FILTRO OLEO NOVO 18_02.xlsx
# sheets/PARAFUSO ARVORE COMANDO.xlsx
# sheets/TAMPA RETOR OLEO.xlsx
# sheets/SENSOR OXIGÊNIO.xlsx
# sheets/FILTRO OLEO - 24_01.xlsx
# sheets/SUPORTE CELULAR 13_02.xlsx
# sheets/SILICONE 15_02_.xlsx
# sheets/FLANGE TAMBOR.xlsx
# sheets/PARAFUSO MAGNETO.xlsx
# sheets/PEDAL FREIO - 01_02.xlsx
# sheets/KIT CILINDRO - 19_01 M.xlsx
# sheets/TAMPA PAINEL.xlsx
# sheets/TRANSMISSÃO PRIMÁRIA.xlsx
# sheets/RETENTOR PINHAO.xlsx
# sheets/EIXO TRANSMISSAO.xlsx
# sheets/OLEO 15_02.xlsx
# sheets/ PARAFUSO PARALAMA.xlsx
# sheets/COXIM ESCAPE.xlsx
# sheets/CAVALETE LATERAL- 02_02.xlsx
# sheets/EIXO CAVALETE_.xlsx
# sheets/AMORTECEDOR NOVO 18_02.xlsx
# sheets/RETENTOR PARTIDA.xlsx
# sheets/BALANÇA- 24_01.xlsx
# sheets/CORRENTE COMANDO 10_02.xlsx
# sheets/ ESTATOR COMPLETO 09_02.xlsx
# sheets/PARAFUSO TAMPA VALVULA.xlsx
# sheets/TENSOR CORRENTE.xlsx
# sheets/CAPA ESTICADOR.xlsx
# sheets/SENSOR ABS.xlsx
# sheets/RETENTOR MAGNETO.xlsx
# sheets/REDE ELASTICA.xlsx
# sheets/GUARNIÇÃO TAMPA PARTIDA.xlsx
# sheets/CHAVETA - 23_01.xlsx
# sheets/SENSOR NEUTRO - 01_02.xlsx
# sheets/CONDUTOR FILTRO AR 08_02.xlsx
# sheets/SENSOR TEMPARATURA OLEO.xlsx
# sheets/EMBREAGEM SECUNDARIA.xlsx
# sheets/DISCO FREIO NOVO 18_02.xlsx
# sheets/MOTOR DE PARTIDA - 19_01.xlsx
# sheets/BOBINA LUZ.xlsx
# sheets/PRISONEIRO COROA.xlsx
# sheets/EIXO TRASMISSAO.xlsx
# sheets/LENTE CARCAÇA PAINEL.xlsx
# sheets/PARAFUSO REGULADOR CABO FREIO.xlsx
# sheets/DIAFRAGMA CARBURADOR.xlsx
# sheets/EIXO BALANÇA - 02_02.xlsx
# sheets/ RETROVISOR 10_02.xlsx
# sheets/REPARO CILINDRO MESTRE.xlsx
# sheets/SENSOR REGULADOR TEMPARATURA.xlsx
# sheets/ALÇA.xlsx
# sheets/BORRACHA PEDALEIRA.xlsx
# sheets/CUBO RODA - 24_01.xlsx
# sheets/RETIFICADOR CORRENTE_.xlsx
# sheets/SENSOR VELOCIDADE.xlsx
# sheets/PASTILHA FREIO NOVO 18_02.xlsx
# sheets/MESA GUIDO 04_02.xlsx
# sheets/JUNTA TAMPA VALVULA.xlsx
# sheets/PARTIDA - 27_01.xlsx
# sheets/CABECOTE MOTOR_.xlsx
# sheets/RETENTOR RODA.xlsx
# sheets/GUARNICAO PONTEIRA.xlsx
# sheets/SOQUETE FAROL - 02_02.xlsx
# sheets/PARALAMA - 19_01.xlsx
# sheets/RETENTOR EMBREAGEM.xlsx
# sheets/INTERRUPTOR FREIO.xlsx
# sheets/KIT JUNTA.xlsx
# sheets/ACIONADOR CORRENTE - 29_01 M.xlsx
# sheets/SUPORTER ADAP PARALAMA NOVO 18_02.xlsx
# sheets/SUPORTE PARALAMA - 29_01.xlsx
# sheets/BUJAO CARTER_.xlsx
# sheets/ EXCENTRICO FREIO 15_02.xlsx
# sheets/TELA FILTRO OLEO 06_02.xlsx
# sheets/RETENTOR VIRABREQUIM.xlsx
# sheets/COXIM CAVALETE CENTRAL.xlsx
# sheets/LANTERNA - 19_01.xlsx
# sheets/KIT REPARO MESA.xlsx
# sheets/PASTILHA DE FREIO 08_02.xlsx
# sheets/FILTRO GASOLINA.xlsx
# sheets/ROLDANAS - 18_01.xlsx
# sheets/ANEL SEGMENTO 06_02.xlsx
# sheets/ESTATOR BOBINA PULSO.xlsx
# sheets/COXIM APOIO.xlsx
# sheets/CABOS NOVOS 17_02.xlsx
# sheets/ESTICADOR CORRENTE 06_02.xlsx
# sheets/CAMARA AR NOVO 17_02.xlsx
# sheets/ARVORE COMANDO - 30_01 M.xlsx
# sheets/EIXO PINHAO.xlsx
# sheets/TAMPA TANQUE.xlsx
# sheets/ENGRENAGEM BOMBA OLEO02_02.xlsx
# sheets/TORNEIRA GASOLINA 03_02.xlsx
# sheets/SUPORTE PLACA.xlsx
# sheets/MANICOTO NOVO 18_02.xlsx
# sheets/VARAO FREIO.xlsx
# sheets/JUNCAO BICO INJETOR.xlsx
# sheets/RETENTOR VALVULA NOVO 18_02.xlsx
# sheets/DIAGRAGMA CARBURADOR.xlsx
# sheets/KIT TRANSMISSAO NOVO 18_02.xlsx
# sheets/TAMPA PARALAMA_.xlsx
# sheets/LAMPADA FREIO_.xlsx
# sheets/PINO GUIA TAMPA LATERAL.xlsx
# sheets/PARAFUSO FILTRO AR.xlsx
# sheets/GUIDO NOVO 18_02.xlsx
# sheets/CARCAÇA ACELERADOR.xlsx
# sheets/EMBREAGEM COMPLETA 05_02.xlsx
# sheets/LUBRIFICANTE 15_02.xlsx
# sheets/RESERVATÓRIO - 29_01.xlsx
# sheets/VISEIRA 26_02.xlsx
# sheets/KIT TRANSMISSÃO.xlsx
# sheets/PRISIONEIRO CILINDRO 06_02.xlsx
# sheets/GUIA CORRENTE 02_02_.xlsx
# sheets/LAMPADA PISCA.xlsx
# sheets/PROTETOR TANQUE NOVO.xlsx
# sheets/GUARDA PÓ BENGALA.xlsx
# sheets/ADITIVO 15_02.xlsx
# sheets/COMBUSTIVEL - 20_01.xlsx
# sheets/ROLAMENTO AGULHA_.xlsx
# sheets/CAVALETE CENTRAL.xlsx
# sheets/VELA 04_02.xlsx
# sheets/RETOR BOMBA OLEO.xlsx
# sheets/CARENAGEM - 18_01.xlsx
# sheets/ALAVANCA FREIO 06_02.xlsx
# sheets/PORCA EIXO RODA.xlsx
# sheets/PARAFUSO PLACA.xlsx
# sheets/REPARO CAPACETE.xlsx
# sheets/GUIDAO - 27_01.xlsx
# sheets/SENSOR VELOCIDADE 26_02.xlsx
# sheets/LAMPADA LED 03_02.xlsx
# sheets/EMBREAGEM PRIMÁRIA.xlsx
# sheets/MOLA CAVALETE CENTRAL.xlsx
# sheets/VARETA VALVULA 06_02.xlsx
# sheets/ENGRENAGEM MOVIDA.xlsx
# sheets/INTERRUPTOR EMBREAGEM - 02_02.xlsx
# sheets/JUNTA MAGNETO.xlsx
# sheets/SENSOR POSIÇÃO ACELERADOR.xlsx
# sheets/JOGO EGRENAGEM.xlsx
# sheets/INTERRUPTOR BUZINA.xlsx
# sheets/DISCO EMBREAGEM 05_02.xlsx
# sheets/PINHAO 09_02.xlsx
# sheets/CABO - 15_01.xlsx
# sheets/FILTRO COMBUSTIVEL 08_02.xlsx
# sheets/CAIXA DIREÇÃO - 30_01.xlsx
# sheets/FILTRO AR.xlsx
# sheets/DISCO FREIO - 01_2.xlsx
# sheets/BENGALA - 20_01.xlsx
# sheets/MANGUEIRA FLEXIVEL FREIO 11_02.xlsx
# sheets/ESTRIBO.xlsx
# sheets/LONA FREIO - 30_01.xlsx
# sheets/BOMBA FREIO.xlsx
# sheets/MAGNETO COMPLETO.xlsx
# sheets/PLACA PARTIDA - 29_01.xlsx
# sheets/EIXO SECUNDÁRIO.xlsx
# sheets/AMORTECEDOR - 14_01.xlsx
# sheets/BOIA AFOGADOR.xlsx
# sheets/GARFO SELETOR.xlsx
# sheets/PINO GUIA MOTOR.xlsx
# sheets/RETENTOR BENGALA.xlsx
# sheets/CAIXA DIREÇÃO - 02_02.xlsx
# sheets/CHAVETA VALVULA.xlsx
# sheets/FAROL - 24_01.xlsx
# sheets/REPARO - 19_01.xlsx
# sheets/PINO GUIA 06_02.xlsx
# sheets/PARAFUSO BOMBA OLEO.xlsx
# sheets/ENGRENAGEM VELCIMETRO - 26_01.xlsx
# sheets/BATERIA 13_02.xlsx
# sheets/SUPORTE PARALAMA.xlsx
# sheets/BALANCIM VALVULAS.xlsx
# sheets/COLEROR ADMISAO NOVO 18_02.xlsx
# sheets/TRAVA GUIDO - 24_01.xlsx
# sheets/REFIL BOMBA COMBUSTIVEL 30_01_.xlsx
# sheets/PARAFUSO RABETA.xlsx
# sheets/EIXO CAMBIO 08_02.xlsx
# sheets/SENSOR HIBRÍDO.xlsx
# sheets/FIACAO PRINCIPAL  11_02.xlsx
# sheets/ESPACADOR 16_02.xlsx
# sheets/MANICOTO - 26_01.xlsx
# sheets/BUJAO CARTER MOTOR.xlsx
# sheets/CARCAÇA FAROL.xlsx
# sheets/KIT TENSOR CORRENTE_.xlsx
# sheets/LUBRIFICANTE ANTIFERRUGEM 15_02.xlsx
# sheets/MANOPLA.xlsx
# sheets/REGULADOR RETIFICADOR 04_02.xlsx
# sheets/CAPA BANCO- 26_01.xlsx
# sheets/BUCHA RODA.xlsx
# sheets/ESPELHO FREIO - 29_01.xlsx
# sheets/ACABAMENTO FAROL.xlsx
# sheets/BICO INJETOR - 30_01 A.xlsx
# sheets/PISCA LED NOVO 18_02.xlsx
# sheets/BUZINA - 02_02.xlsx
# sheets/PARALAMA NOVO 18_02.xlsx
# sheets/PEDAL - 24_01.xlsx
# sheets/PISTONETE CARBURADOR.xlsx
# sheets/PEDAL PARTIDA NOVO 18_02.xlsx
# sheets/PROTETOR TANQUE 12_02.xlsx
# sheets/ARO RODAS 12_02.xlsx
# sheets/PNEUS 12_02.xlsx
# sheets/GRAXA 15_02.xlsx
# sheets/MANGUEIRA COMBUSTIVEL 11_02.xlsx
# sheets/EMENDA CORRENTE 09_02.xlsx
# sheets/BUCHA QUADRO  08_02.xlsx
# sheets/BURRINHO PINCA - 21_01.xlsx
# sheets/INTERRUPTOR  FAROL 03_02.xlsx
# sheets/KIT-A.xlsx
# sheets/ANEL VEDACAO.xlsx
# sheets/ CILINDRO MESTRE 11_02.xlsx
# sheets/CHAVE LUZ.xlsx
# sheets/SENSOR TEMPERATURA ÁGUA.xlsx
# sheets/COXIM AMORTECEDOR.xlsx
# sheets/GUARNICAO CARBURADOR.xlsx
# sheets/BRACO FREIO.xlsx
# sheets/ARO FAROL - 19_01.xlsx
# sheets/PEDAL PARTIDA - 01_02.xlsx
# sheets/PRISIONEIRO ESCAPAMENTO.xlsx
# sheets/MANETE - 20_01.xlsx
# sheets/ PUNHO PARTIDA.xlsx
# sheets/KIT ANEL MOTOR.xlsx
# sheets/TAMPA DO PINHAO - 19_01.xlsx
# sheets/JOGO INJECAO.xlsx
# sheets/PAINEL - 29_01.xlsx
# sheets/CACHIMBO - 01_02.xlsx
# sheets/DUTO AR 08_02.xlsx
# sheets/TAMPA LATERAL 08_02.xlsx
# sheets/COLETOR ADMISSAO - 01_02.xlsx
# sheets/SENSOR INCLINAÇÃO.xlsx
# sheets/RETENTOR TAMPA CABEÇOTE.xlsx
# sheets/PROTETOR CORRENTE.xlsx
# sheets/CORREIA DENTADA.xlsx
# sheets/SUPORTE ESCAPAMENTO.xlsx
# sheets/AGULHA BOIA.xlsx
# sheets/GUARNICAO FREIO.xlsx
# sheets/INTERRUPTOR FREIO - 01_02.xlsx
# sheets/CAPA CHUVA- 29_01.xlsx
# sheets/JUNTA COLETOR.xlsx
# sheets/KIT VALVULA AFOGADOR.xlsx
# sheets/ROLETE TRANSMISSÃO.xlsx
# sheets/INTERRUPTOR PARTIDA - 02_02.xlsx
# sheets/CARCAÇA EXTERNA EMBREAGEM.xlsx
# sheets/VELOCIMETRO.xlsx
# sheets/INTERRUPTOR PISCA - 02_02.xlsx
# sheets/RETENTOR VALVULA.xlsx
# sheets/CHAVE DE LUZ 03_02.xlsx
# sheets/SUPORTE PAINEL.xlsx
# sheets/BUCHA COROA.xlsx
# sheets/TENSIONADOR.xlsx
# sheets/EIXO BALANCIM.xlsx
# sheets/BOMBA ÓLEO - 26_01.xlsx
# sheets/FILTRO COMBUSTIVEL.xlsx
# sheets/MOLA - 26_01.xlsx
# sheets/COXIM - 24_01.xlsx
# sheets/ANEL ELASTICOR.xlsx
# sheets/SENSOR ATUADOR MARCHA LENTA.xlsx
# sheets/LAMPADA PAINEL_.xlsx
# sheets/RAIO 24_02.xlsx
# sheets/CAMARA AR 06_02.xlsx
# sheets/EIXO GARFO_.xlsx
# sheets/PARAFUSO CARENAGEM.xlsx
# sheets/ESTICADOR CORRENTE.xlsx
# sheets/EIXO PEDAL.xlsx
# sheets/ROLETE EMBREAGEM.xlsx
# sheets/BRACO ANCORAGEM.xlsx
# sheets/SANFONA - 14_01.xlsx
# sheets/JOGO PRATO SEDE VALVULA.xlsx
# sheets/ROLAMENTO - 27_01.xlsx
# sheets/PROTETOR ESCAPAMENTO.xlsx
# sheets/BUCHA GARFO.xlsx
# sheets/EIXO SELETOR.xlsx
# sheets/ARRUELA COROA 06_02.xlsx
# sheets/BUCHA BENGALA.xlsx
# sheets/KIT POLIA.xlsx
# sheets/COROA - 29_01.xlsx
# sheets/GUIA CORRENTE - 21_01.xlsx
# sheets/VALVULA ESCAPE.xlsx
# sheets/KIT TRANSMISSÃO - 14_01.xlsx
# sheets/BOBINA IGNICAO E  PULSO 03_02.xlsx
# sheets/PISCAS - 18_01.xlsx
# sheets/ESCOVA ARRANQUE - 02_02.xlsx
# sheets/COXIM PARALAMA.xlsx
# sheets/RELE PISCA 06_02.xlsx
# sheets/COXIM LANTERNA.xlsx
# sheets/PARAFUSO MOTOR CABECOTE.xlsx
# sheets/VOLANTE MAGNETO.xlsx
# sheets/REPARO CARBURADOR.xlsx
# sheets/ANEL ELASTICO COROA.xlsx
# sheets/TAMPA BUJAO CARTER.xlsx
# sheets/RELÉ PARTIDA - 29_01.xlsx
# sheets/DESCARBONIZANTE 15_02.xlsx
# sheets/BOBINA PULSO.xlsx
# sheets/ELASTIC.xlsx
# sheets/BURRINHO FREIO.xlsx
# sheets/JUNTA EMBREAGEM.xlsx
# sheets/CAPACETE 13_02.xlsx
# sheets/CARCAÇA PAINEL 28_01.xlsx
# sheets/SENSOR TPS.xlsx
# sheets/BUCHA BALANCA.xlsx
# sheets/SUPORTE CHAPA FERRO 26_02.xlsx
# sheets/BUZINA NOVO 18_02.xlsx
# sheets/VALVULA - 28_01 M.xlsx
# sheets/CARBURADOR - 19_01 A.xlsx
# sheets/KIT BIELA 04_02.xlsx
# sheets/CAMBIO COMPLETO.xlsx
# sheets/PEDAL CAMBIO - 01_02.xlsx
# sheets/GUARNICAO ESCAPE 08_02.xlsx
# sheets/CHAVE IGNIÇÃO - 29_01.xlsx
# <class 'pandas.DataFrame'>
# RangeIndex: 3180 entries, 0 to 3179
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CÓD. BARRA  3023 non-null   str
#  1   DESCRIÇÃO   3055 non-null   str
#  2   QUANTIDADE  3020 non-null   str
#  3   PREÇO       1656 non-null   str
#  4   DISCRIÇÃO   22 non-null     str
# dtypes: str(5)
# memory usage: 124.3 KB

# %%
for file in files:
    df = pd.read_excel(file, usecols=[0, 1, 2, 3], dtype=str)
    df = df.dropna(how='all')
    df.to_excel(f'./processed_sheets/{file.name}')
